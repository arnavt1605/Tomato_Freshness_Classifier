# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavt1605/Tomato_Freshness_Classifier/blob/main/Custom_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, random_split
from torchmetrics.classification import Accuracy
import torchmetrics

device= torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.11/dist-packages (1.8.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.6.0+cu124)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (0.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.2.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.14.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)

# %%
import zipfile
with zipfile.ZipFile("tomato_data.zip", 'r') as zip:
  zip.extractall("tomato_data")

# %%
path= '/content/tomato_data'

# %%
train_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),  #Removed RandomCrop(32) as it resized the image back
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform= transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_path= '/content/tomato_data/data/Training_set'
test_path= '/content/tomato_data/data/Testing_set'

train_data= datasets.ImageFolder(root=train_path, transform= train_transform)
test_set= datasets.ImageFolder(root=test_path, transform= test_transform)

for (img, label) in train_data:
  print(img.shape)
  break
# Out:
# torch.Size([3, 128, 128])

# %%
train_size = int(0.85 * len(train_data))
val_size   = len(train_data) - train_size

train_set, val_set = random_split(train_data, [train_size, val_size], generator=torch.Generator().manual_seed(42))

# %%
train_loader = DataLoader(train_set, batch_size=128, shuffle=True)
val_loader   = DataLoader(val_set, batch_size=128, shuffle=False)
test_loader  = DataLoader(test_set,  batch_size=128, shuffle=False)


for (img, label) in train_loader:
  print(img.shape)
  break
# Out:
# torch.Size([128, 3, 128, 128])

# %%
class CNN(nn.Module):
  def __init__(self):
    super().__init__()

    # Input image is 3x128x128

    self.stack= nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),  # Equivalent to nn.MaxPool2d(kernel_size=2, stride=2, padding=0)


        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),

        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
        nn.BatchNorm2d(128),
        nn.ReLU(),
        nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
        nn.BatchNorm2d(128),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),

        nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
        nn.BatchNorm2d(256),
        nn.ReLU(),
        nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
        nn.BatchNorm2d(256),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )

    self.classifier= nn.Sequential(
        nn.Flatten(),
        nn.Linear(in_features=16384, out_features=512),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.Linear(in_features=512, out_features=10)
    )

  def forward(self, x):
    x=self.stack(x)
    x=self.classifier(x)
    return x

# %%
model= CNN().to(device)

# %%
loss_function= nn.CrossEntropyLoss()

# %%
optimizer= torch.optim.Adam(model.parameters(), lr= 0.001)

scheduler= torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode= "max", factor= 0.5, patience= 3)

# %%
def train(dataloader, model, loss_function, optimizer):
  model.train()
  total_loss= 0

  for batch, (image, label) in enumerate(dataloader):
    image= image.to(device)
    label= label.to(device)

    prediction= model(image)
    loss= loss_function(prediction, label)

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    total_loss+= loss

  avg_loss= total_loss / len(dataloader)
  print(f"Training Average Loss: {avg_loss:.4f}")

# %%
val_accuracy = Accuracy(task="multiclass", num_classes=10).to(device)

def validate(dataloader, model, loss_function):
    model.eval()
    total_loss = 0
    val_accuracy.reset()

    with torch.no_grad():
        for image, label in dataloader:
            image = image.to(device)
            label = label.to(device)

            pred = model(image)
            loss = loss_function(pred, label)
            total_loss += loss

            val_accuracy.update(pred, label)

    avg_loss = total_loss / len(dataloader)
    accuracy = val_accuracy.compute() * 100  # Convert to %

    print(f"Validation Loss: {avg_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")

    return accuracy

# %%
test_accuracy = Accuracy(task="multiclass", num_classes=10).to(device)

def test(dataloader, model, loss_function):
    model.eval()
    total_loss = 0
    test_accuracy.reset()   #Reset metric state for each epoch

    with torch.no_grad():
        for image, label in dataloader:
            image = image.to(device)
            label = label.to(device)

            pred = model(image)
            loss = loss_function(pred, label)
            total_loss += loss

            test_accuracy.update(pred, label)

    avg_loss = total_loss / len(dataloader)
    accuracy = test_accuracy.compute() * 100  # Convert to %

    print(f"Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.2f}%")

    return accuracy

# %%
epochs = 90
for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}/{epochs}")
    train(train_loader, model, loss_function, optimizer)
    val_acc = validate(val_loader, model, loss_function)
    scheduler.step(val_acc)
print("\n")
print("\n")
print("\n")
print("-----------------------------------------------------------------")
print("\n")
print("\n")
print("\n")
test(test_loader, model, loss_function)
# Out:
# Epoch 1/90
# Training Average Loss: 1.6756
# Validation Loss: 1.7587, Validation Accuracy: 45.77%
#
# Epoch 2/90
# Training Average Loss: 1.6757
# Validation Loss: 1.8234, Validation Accuracy: 44.99%
#
# Epoch 3/90
# Training Average Loss: 1.6548
# Validation Loss: 1.7475, Validation Accuracy: 46.42%
#
# Epoch 4/90
# Training Average Loss: 1.6112
# Validation Loss: 1.7117, Validation Accuracy: 47.72%
#
# Epoch 5/90
# Training Average Loss: 1.6005
# Validation Loss: 1.7545, Validation Accuracy: 46.03%
#
# Epoch 6/90
# Training Average Loss: 1.6704
# Validation Loss: 1.7268, Validation Accuracy: 45.90%
#
# Epoch 7/90
# Training Average Loss: 1.5818
# Validation Loss: 1.7361, Validation Accuracy: 46.68%
#
# Epoch 8/90
# Training Average Loss: 1.6248
# Validation Loss: 1.6995, Validation Accuracy: 46.16%
#
# Epoch 9/90
# Training Average Loss: 1.5789
# Validation Loss: 1.7568, Validation Accuracy: 46.29%
#
# Epoch 10/90
# Training Average Loss: 1.5492
# Validation Loss: 1.6927, Validation Accuracy: 47.72%
#
# Epoch 11/90
# Training Average Loss: 1.4793
# Validation Loss: 1.6349, Validation Accuracy: 48.24%
#
# Epoch 12/90
# Training Average Loss: 1.4678
# Validation Loss: 1.6522, Validation Accuracy: 48.37%
#
# Epoch 13/90
# Training Average Loss: 1.4536
# Validation Loss: 1.6417, Validation Accuracy: 48.63%
#
# Epoch 14/90
# Training Average Loss: 1.5253
# Validation Loss: 1.6461, Validation Accuracy: 48.76%
#
# Epoch 15/90
# Training Average Loss: 1.5239
# Validation Loss: 1.6313, Validation Accuracy: 49.93%
#
# Epoch 16/90
# Training Average Loss: 1.5625
# Validation Loss: 1.6583, Validation Accuracy: 49.02%
#
# Epoch 17/90
# Training Average Loss: 1.4736
# Validation Loss: 1.6649, Validation Accuracy: 49.02%
#
# Epoch 18/90
# Training Average Loss: 1.4649
# Validation Loss: 1.6958, Validation Accuracy: 50.85%
#
# Epoch 19/90
# Training Average Loss: 1.4766
# Validation Loss: 1.6074, Validation Accuracy: 49.93%
#
# Epoch 20/90
# Training Average Loss: 1.5137
# Validation Loss: 1.5841, Validation Accuracy: 50.20%
#
# Epoch 21/90
# Training Average Loss: 1.4515
# Validation Loss: 1.5752, Validation Accuracy: 49.93%
#
# Epoch 22/90
# Training Average Loss: 1.4051
# Validation Loss: 1.5473, Validation Accuracy: 49.80%
#
# Epoch 23/90
# Training Average Loss: 1.4692
# Validation Loss: 1.5779, Validation Accuracy: 50.85%
#
# Epoch 24/90
# Training Average Loss: 1.3844
# Validation Loss: 1.5600, Validation Accuracy: 49.02%
#
# Epoch 25/90
# Training Average Loss: 1.3904
# Validation Loss: 1.5142, Validation Accuracy: 50.20%
#
# Epoch 26/90
# Training Average Loss: 1.4764
# Validation Loss: 1.5927, Validation Accuracy: 50.72%
#
# Epoch 27/90
# Training Average Loss: 1.3705
# Validation Loss: 1.4980, Validation Accuracy: 51.11%
#
# Epoch 28/90
# Training Average Loss: 1.3515
# Validation Loss: 1.5948, Validation Accuracy: 50.20%
#
# Epoch 29/90
# Training Average Loss: 1.4153
# Validation Loss: 1.5504, Validation Accuracy: 50.85%
#
# Epoch 30/90
# Training Average Loss: 1.3580
# Validation Loss: 1.5317, Validation Accuracy: 50.59%
#
# Epoch 31/90
# Training Average Loss: 1.4565
# Validation Loss: 1.4713, Validation Accuracy: 50.20%
#
# Epoch 32/90
# Training Average Loss: 1.4179
# Validation Loss: 1.5176, Validation Accuracy: 50.59%
#
# Epoch 33/90
# Training Average Loss: 1.3673
# Validation Loss: 1.4633, Validation Accuracy: 51.24%
#
# Epoch 34/90
# Training Average Loss: 1.3287
# Validation Loss: 1.4829, Validation Accuracy: 51.89%
#
# Epoch 35/90
# Training Average Loss: 1.3848
# Validation Loss: 1.5395, Validation Accuracy: 50.85%
#
# Epoch 36/90
# Training Average Loss: 1.3638
# Validation Loss: 1.5266, Validation Accuracy: 50.20%
#
# Epoch 37/90
# Training Average Loss: 1.3478
# Validation Loss: 1.5395, Validation Accuracy: 51.24%
#
# Epoch 38/90
# Training Average Loss: 1.4255
# Validation Loss: 1.4724, Validation Accuracy: 50.98%
#
# Epoch 39/90
# Training Average Loss: 1.4123
# Validation Loss: 1.4645, Validation Accuracy: 51.89%
#
# Epoch 40/90
# Training Average Loss: 1.3786
# Validation Loss: 1.5369, Validation Accuracy: 51.37%
#
# Epoch 41/90
# Training Average Loss: 1.3602
# Validation Loss: 1.5117, Validation Accuracy: 51.11%
#
# Epoch 42/90
# Training Average Loss: 1.3056
# Validation Loss: 1.5496, Validation Accuracy: 51.63%
#
# Epoch 43/90
# Training Average Loss: 1.3669
# Validation Loss: 1.5860, Validation Accuracy: 51.24%
#
# Epoch 44/90
# Training Average Loss: 1.3105
# Validation Loss: 1.4775, Validation Accuracy: 51.76%
#
# Epoch 45/90
# Training Average Loss: 1.3732
# Validation Loss: 1.4742, Validation Accuracy: 51.76%
#
# Epoch 46/90
# Training Average Loss: 1.3042
# Validation Loss: 1.5462, Validation Accuracy: 52.41%
#
# Epoch 47/90
# Training Average Loss: 1.3746
# Validation Loss: 1.4457, Validation Accuracy: 52.67%
#
# Epoch 48/90
# Training Average Loss: 1.3719
# Validation Loss: 1.4470, Validation Accuracy: 52.54%
#
# Epoch 49/90
# Training Average Loss: 1.2989
# Validation Loss: 1.4663, Validation Accuracy: 50.72%
#
# Epoch 50/90
# Training Average Loss: 1.3007
# Validation Loss: 1.4230, Validation Accuracy: 51.89%
#
# Epoch 51/90
# Training Average Loss: 1.3595
# Validation Loss: 1.4359, Validation Accuracy: 52.28%
#
# Epoch 52/90
# Training Average Loss: 1.2889
# Validation Loss: 1.5524, Validation Accuracy: 50.72%
#
# Epoch 53/90
# Training Average Loss: 1.2999
# Validation Loss: 1.5369, Validation Accuracy: 51.63%
#
# Epoch 54/90
# Training Average Loss: 1.3720
# Validation Loss: 1.4673, Validation Accuracy: 51.50%
#
# Epoch 55/90
# Training Average Loss: 1.3563
# Validation Loss: 1.4383, Validation Accuracy: 50.85%
#
# Epoch 56/90
# Training Average Loss: 1.3204
# Validation Loss: 1.5051, Validation Accuracy: 53.19%
#
# Epoch 57/90
# Training Average Loss: 1.3060
# Validation Loss: 1.5160, Validation Accuracy: 53.19%
#
# Epoch 58/90
# Training Average Loss: 1.2837
# Validation Loss: 1.4321, Validation Accuracy: 51.89%
#
# Epoch 59/90
# Training Average Loss: 1.3875
# Validation Loss: 1.5185, Validation Accuracy: 51.63%
#
# Epoch 60/90
# Training Average Loss: 1.4024
# Validation Loss: 1.5611, Validation Accuracy: 51.76%
#
# Epoch 61/90
# Training Average Loss: 1.2923
# Validation Loss: 1.5668, Validation Accuracy: 50.72%
#
# Epoch 62/90
# Training Average Loss: 1.2954
# Validation Loss: 1.4341, Validation Accuracy: 51.63%
#
# Epoch 63/90
# Training Average Loss: 1.3907
# Validation Loss: 1.5327, Validation Accuracy: 51.37%
#
# Epoch 64/90
# Training Average Loss: 1.2999
# Validation Loss: 1.5366, Validation Accuracy: 51.50%
#
# Epoch 65/90
# Training Average Loss: 1.3510
# Validation Loss: 1.4996, Validation Accuracy: 51.63%
#
# Epoch 66/90
# Training Average Loss: 1.2986
# Validation Loss: 1.5016, Validation Accuracy: 51.37%
#
# Epoch 67/90
# Training Average Loss: 1.3013
# Validation Loss: 1.4506, Validation Accuracy: 50.72%
#
# Epoch 68/90
# Training Average Loss: 1.4365
# Validation Loss: 1.4787, Validation Accuracy: 52.54%
#
# Epoch 69/90
# Training Average Loss: 1.5082
# Validation Loss: 1.4263, Validation Accuracy: 51.50%
#
# Epoch 70/90
# Training Average Loss: 1.4404
# Validation Loss: 1.5138, Validation Accuracy: 51.50%
#
# Epoch 71/90
# Training Average Loss: 1.3051
# Validation Loss: 1.4915, Validation Accuracy: 50.46%
#
# Epoch 72/90
# Training Average Loss: 1.2907
# Validation Loss: 1.5158, Validation Accuracy: 52.28%
#
# Epoch 73/90
# Training Average Loss: 1.3528
# Validation Loss: 1.5602, Validation Accuracy: 53.19%
#
# Epoch 74/90
# Training Average Loss: 1.3550
# Validation Loss: 1.5430, Validation Accuracy: 52.54%
#
# Epoch 75/90
# Training Average Loss: 1.3781
# Validation Loss: 1.5977, Validation Accuracy: 51.76%
#
# Epoch 76/90
# Training Average Loss: 1.2910
# Validation Loss: 1.5444, Validation Accuracy: 52.15%
#
# Epoch 77/90
# Training Average Loss: 1.3711
# Validation Loss: 1.5387, Validation Accuracy: 52.02%
#
# Epoch 78/90
# Training Average Loss: 1.3862
# Validation Loss: 1.5282, Validation Accuracy: 52.41%
#
# Epoch 79/90
# Training Average Loss: 1.3037
# Validation Loss: 1.5326, Validation Accuracy: 52.28%
#
# Epoch 80/90
# Training Average Loss: 1.3520
# Validation Loss: 1.4597, Validation Accuracy: 52.28%
#
# Epoch 81/90
# Training Average Loss: 1.3266
# Validation Loss: 1.4888, Validation Accuracy: 52.15%
#
# Epoch 82/90
# Training Average Loss: 1.2847
# Validation Loss: 1.5337, Validation Accuracy: 51.37%
#
# Epoch 83/90
# Training Average Loss: 1.3614
# Validation Loss: 1.5978, Validation Accuracy: 51.76%
#
# Epoch 84/90
# Training Average Loss: 1.3507
# Validation Loss: 1.5361, Validation Accuracy: 52.28%
#
# Epoch 85/90
# Training Average Loss: 1.3118
# Validation Loss: 1.4337, Validation Accuracy: 51.89%
#
# Epoch 86/90
# Training Average Loss: 1.2958
# Validation Loss: 1.5018, Validation Accuracy: 52.15%
#
# Epoch 87/90
# Training Average Loss: 1.2971
# Validation Loss: 1.5538, Validation Accuracy: 52.54%
#
# Epoch 88/90
# Training Average Loss: 1.3007
# Validation Loss: 1.5218, Validation Accuracy: 52.15%
#
# Epoch 89/90
# Training Average Loss: 1.3598
# Validation Loss: 1.4272, Validation Accuracy: 51.50%
#
# Epoch 90/90
# Training Average Loss: 1.2950
# Validation Loss: 1.4911, Validation Accuracy: 50.98%
#
#
#
#
#
#
# -----------------------------------------------------------------
#
#
#
#
#
#
# Test Loss: 1.3408, Test Accuracy: 53.02%
# tensor(53.0196, device='cuda:0')
