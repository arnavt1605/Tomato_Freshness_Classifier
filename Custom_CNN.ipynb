# %%
import os
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, random_split
from torchmetrics.classification import Accuracy
import torchmetrics

device= torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.11/dist-packages (1.8.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.6.0+cu124)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (0.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.2.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.14.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)

# %%
import zipfile
with zipfile.ZipFile("tomato_data.zip", 'r') as zip:
  zip.extractall("tomato_data")

# %%
path= '/content/tomato_data'

# %%
train_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),  #Removed RandomCrop(32) as it resized the image back
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform= transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_path= '/content/tomato_data/data/Training_set'
test_path= '/content/tomato_data/data/Testing_set'

train_data= datasets.ImageFolder(root=train_path, transform= train_transform)
test_set= datasets.ImageFolder(root=test_path, transform= test_transform)

for (img, label) in train_data:
  print(img.shape)
  break
# Out:
# torch.Size([3, 128, 128])

# %%
train_size = int(0.85 * len(train_data))
val_size   = len(train_data) - train_size

train_set, val_set = random_split(train_data, [train_size, val_size], generator=torch.Generator().manual_seed(42))

# %%
train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
val_loader   = DataLoader(val_set, batch_size=64, shuffle=False)
test_loader  = DataLoader(test_set,  batch_size=64, shuffle=False)


for (img, label) in train_loader:
  print(img.shape)
  break
# Out:
# torch.Size([64, 3, 128, 128])

# %%
class CNN(nn.Module):
  def __init__(self):
    super().__init__()

    # Input image is 3x128x128

    self.stack= nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),  # Equivalent to nn.MaxPool2d(kernel_size=2, stride=2, padding=0)


        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),

        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
        nn.BatchNorm2d(128),
        nn.ReLU(),
        nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
        nn.BatchNorm2d(128),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),

        nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
        nn.BatchNorm2d(256),
        nn.ReLU(),
        nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
        nn.BatchNorm2d(256),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2),

        nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1),
        nn.BatchNorm2d(512),
        nn.ReLU(),
        nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1),
        nn.BatchNorm2d(512),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )

    self.classifier= nn.Sequential(
        nn.Flatten(),
        nn.Linear(in_features=512*4*4, out_features=512),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.Linear(in_features=512, out_features=10)
    )

  def forward(self, x):
    x=self.stack(x)
    x=self.classifier(x)
    return x

# %%
model= CNN().to(device)

# %%
loss_function= nn.CrossEntropyLoss()

# %%
optimizer= torch.optim.Adam(model.parameters(), lr= 0.001)

scheduler= torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode= "max", factor= 0.5, patience= 3)

# %%
def train(dataloader, model, loss_function, optimizer):
  model.train()
  total_loss= 0

  for batch, (image, label) in enumerate(dataloader):
    image= image.to(device)
    label= label.to(device)

    prediction= model(image)
    loss= loss_function(prediction, label)

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    total_loss+= loss

  avg_loss= total_loss / len(dataloader)
  print(f"Training Average Loss: {avg_loss:.4f}")

# %%
val_accuracy = Accuracy(task="multiclass", num_classes=10).to(device)

def validate(dataloader, model, loss_function):
    model.eval()
    total_loss = 0
    val_accuracy.reset()

    with torch.no_grad():
        for image, label in dataloader:
            image = image.to(device)
            label = label.to(device)

            pred = model(image)
            loss = loss_function(pred, label)
            total_loss += loss

            val_accuracy.update(pred, label)

    avg_loss = total_loss / len(dataloader)
    accuracy = val_accuracy.compute() * 100  # Convert to %

    print(f"Validation Loss: {avg_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")

    return accuracy

# %%
test_accuracy = Accuracy(task="multiclass", num_classes=10).to(device)

def test(dataloader, model, loss_function):
    model.eval()
    total_loss = 0
    test_accuracy.reset()   #Reset metric state for each epoch

    with torch.no_grad():
        for image, label in dataloader:
            image = image.to(device)
            label = label.to(device)

            pred = model(image)
            loss = loss_function(pred, label)
            total_loss += loss

            test_accuracy.update(pred, label)

    avg_loss = total_loss / len(dataloader)
    accuracy = test_accuracy.compute() * 100  # Convert to %

    print(f"Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.2f}%")

    return accuracy

# %%
epochs = 90
for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}/{epochs}")
    train(train_loader, model, loss_function, optimizer)
    val_acc = validate(val_loader, model, loss_function)
    scheduler.step(val_acc)
print("\n")
print("-----------------------------------------------------------------")
print("\n")
test(test_loader, model, loss_function)
# Out:
# Epoch 1/90
# Training Average Loss: 1.7365
# Validation Loss: 1.8067, Validation Accuracy: 44.34%
#
# Epoch 2/90
# Training Average Loss: 1.6705
# Validation Loss: 1.8014, Validation Accuracy: 44.34%
#
# Epoch 3/90
# Training Average Loss: 1.6427
# Validation Loss: 1.8280, Validation Accuracy: 44.34%
#
# Epoch 4/90
# Training Average Loss: 1.6229
# Validation Loss: 1.7332, Validation Accuracy: 44.34%
#
# Epoch 5/90
# Training Average Loss: 1.6877
# Validation Loss: 1.7711, Validation Accuracy: 44.60%
#
# Epoch 6/90
# Training Average Loss: 1.8430
# Validation Loss: 1.7733, Validation Accuracy: 44.47%
#
# Epoch 7/90
# Training Average Loss: 1.6977
# Validation Loss: 1.8688, Validation Accuracy: 44.73%
#
# Epoch 8/90
# Training Average Loss: 1.6833
# Validation Loss: 1.7728, Validation Accuracy: 44.99%
#
# Epoch 9/90
# Training Average Loss: 1.6161
# Validation Loss: 1.7192, Validation Accuracy: 45.38%
#
# Epoch 10/90
# Training Average Loss: 1.6447
# Validation Loss: 1.7106, Validation Accuracy: 45.64%
#
# Epoch 11/90
# Training Average Loss: 1.5979
# Validation Loss: 1.7152, Validation Accuracy: 45.90%
#
# Epoch 12/90
# Training Average Loss: 1.5705
# Validation Loss: 1.6781, Validation Accuracy: 46.03%
#
# Epoch 13/90
# Training Average Loss: 1.5926
# Validation Loss: 1.6896, Validation Accuracy: 45.90%
#
# Epoch 14/90
# Training Average Loss: 1.5374
# Validation Loss: 1.6759, Validation Accuracy: 46.68%
#
# Epoch 15/90
# Training Average Loss: 1.8157
# Validation Loss: 1.7085, Validation Accuracy: 45.12%
#
# Epoch 16/90
# Training Average Loss: 1.7470
# Validation Loss: 1.8086, Validation Accuracy: 44.47%
#
# Epoch 17/90
# Training Average Loss: 1.6645
# Validation Loss: 1.7475, Validation Accuracy: 44.60%
#
# Epoch 18/90
# Training Average Loss: 1.6151
# Validation Loss: 1.7044, Validation Accuracy: 46.03%
#
# Epoch 19/90
# Training Average Loss: 1.5896
# Validation Loss: 1.6486, Validation Accuracy: 46.16%
#
# Epoch 20/90
# Training Average Loss: 1.5459
# Validation Loss: 1.6524, Validation Accuracy: 46.55%
#
# Epoch 21/90
# Training Average Loss: 1.5684
# Validation Loss: 1.6301, Validation Accuracy: 47.07%
#
# Epoch 22/90
# Training Average Loss: 1.5276
# Validation Loss: 1.6118, Validation Accuracy: 47.85%
#
# Epoch 23/90
# Training Average Loss: 1.5121
# Validation Loss: 1.6046, Validation Accuracy: 48.50%
#
# Epoch 24/90
# Training Average Loss: 1.5271
# Validation Loss: 1.6201, Validation Accuracy: 48.24%
#
# Epoch 25/90
# Training Average Loss: 1.5221
# Validation Loss: 1.6027, Validation Accuracy: 47.46%
#
# Epoch 26/90
# Training Average Loss: 1.5152
# Validation Loss: 1.5980, Validation Accuracy: 48.76%
#
# Epoch 27/90
# Training Average Loss: 1.4916
# Validation Loss: 1.5946, Validation Accuracy: 48.50%
#
# Epoch 28/90
# Training Average Loss: 1.4934
# Validation Loss: 1.5474, Validation Accuracy: 48.50%
#
# Epoch 29/90
# Training Average Loss: 1.5346
# Validation Loss: 1.5647, Validation Accuracy: 49.93%
#
# Epoch 30/90
# Training Average Loss: 1.5580
# Validation Loss: 1.6475, Validation Accuracy: 47.98%
#
# Epoch 31/90
# Training Average Loss: 1.4546
# Validation Loss: 1.6322, Validation Accuracy: 49.54%
#
# Epoch 32/90
# Training Average Loss: 1.4677
# Validation Loss: 1.5536, Validation Accuracy: 49.80%
#
# Epoch 33/90
# Training Average Loss: 1.4324
# Validation Loss: 1.5487, Validation Accuracy: 50.72%
#
# Epoch 34/90
# Training Average Loss: 1.4425
# Validation Loss: 1.5259, Validation Accuracy: 48.89%
#
# Epoch 35/90
# Training Average Loss: 1.4622
# Validation Loss: 1.5338, Validation Accuracy: 49.41%
#
# Epoch 36/90
# Training Average Loss: 1.4640
# Validation Loss: 1.5922, Validation Accuracy: 48.63%
#
# Epoch 37/90
# Training Average Loss: 1.4466
# Validation Loss: 1.5397, Validation Accuracy: 50.46%
#
# Epoch 38/90
# Training Average Loss: 1.3914
# Validation Loss: 1.5408, Validation Accuracy: 49.67%
#
# Epoch 39/90
# Training Average Loss: 1.4175
# Validation Loss: 1.5238, Validation Accuracy: 49.93%
#
# Epoch 40/90
# Training Average Loss: 1.4172
# Validation Loss: 1.5207, Validation Accuracy: 50.72%
#
# Epoch 41/90
# Training Average Loss: 1.4022
# Validation Loss: 1.4913, Validation Accuracy: 50.33%
#
# Epoch 42/90
# Training Average Loss: 1.4027
# Validation Loss: 1.5028, Validation Accuracy: 50.72%
#
# Epoch 43/90
# Training Average Loss: 1.3970
# Validation Loss: 1.5330, Validation Accuracy: 50.72%
#
# Epoch 44/90
# Training Average Loss: 1.3927
# Validation Loss: 1.5216, Validation Accuracy: 50.20%
#
# Epoch 45/90
# Training Average Loss: 1.3707
# Validation Loss: 1.5064, Validation Accuracy: 50.59%
#
# Epoch 46/90
# Training Average Loss: 1.3617
# Validation Loss: 1.4915, Validation Accuracy: 51.11%
#
# Epoch 47/90
# Training Average Loss: 1.3832
# Validation Loss: 1.5138, Validation Accuracy: 50.07%
#
# Epoch 48/90
# Training Average Loss: 1.3649
# Validation Loss: 1.4719, Validation Accuracy: 50.33%
#
# Epoch 49/90
# Training Average Loss: 1.3719
# Validation Loss: 1.5016, Validation Accuracy: 50.98%
#
# Epoch 50/90
# Training Average Loss: 1.3437
# Validation Loss: 1.5359, Validation Accuracy: 51.37%
#
# Epoch 51/90
# Training Average Loss: 1.3495
# Validation Loss: 1.4999, Validation Accuracy: 51.76%
#
# Epoch 52/90
# Training Average Loss: 1.3712
# Validation Loss: 1.5288, Validation Accuracy: 51.24%
#
# Epoch 53/90
# Training Average Loss: 1.3522
# Validation Loss: 1.4610, Validation Accuracy: 51.37%
#
# Epoch 54/90
# Training Average Loss: 1.3767
# Validation Loss: 1.5186, Validation Accuracy: 51.37%
#
# Epoch 55/90
# Training Average Loss: 1.3628
# Validation Loss: 1.5444, Validation Accuracy: 51.76%
#
# Epoch 56/90
# Training Average Loss: 1.3381
# Validation Loss: 1.5035, Validation Accuracy: 51.76%
#
# Epoch 57/90
# Training Average Loss: 1.3474
# Validation Loss: 1.5414, Validation Accuracy: 50.98%
#
# Epoch 58/90
# Training Average Loss: 1.3639
# Validation Loss: 1.4822, Validation Accuracy: 50.46%
#
# Epoch 59/90
# Training Average Loss: 1.3628
# Validation Loss: 1.4948, Validation Accuracy: 52.02%
#
# Epoch 60/90
# Training Average Loss: 1.3544
# Validation Loss: 1.4780, Validation Accuracy: 51.37%
#
# Epoch 61/90
# Training Average Loss: 1.3586
# Validation Loss: 1.4928, Validation Accuracy: 50.85%
#
# Epoch 62/90
# Training Average Loss: 1.3383
# Validation Loss: 1.4560, Validation Accuracy: 50.98%
#
# Epoch 63/90
# Training Average Loss: 1.3525
# Validation Loss: 1.4905, Validation Accuracy: 51.11%
#
# Epoch 64/90
# Training Average Loss: 1.3512
# Validation Loss: 1.4827, Validation Accuracy: 50.72%
#
# Epoch 65/90
# Training Average Loss: 1.3460
# Validation Loss: 1.4687, Validation Accuracy: 51.89%
#
# Epoch 66/90
# Training Average Loss: 1.3241
# Validation Loss: 1.5091, Validation Accuracy: 51.24%
#
# Epoch 67/90
# Training Average Loss: 1.3544
# Validation Loss: 1.4904, Validation Accuracy: 51.50%
#
# Epoch 68/90
# Training Average Loss: 1.4295
# Validation Loss: 1.5027, Validation Accuracy: 51.11%
#
# Epoch 69/90
# Training Average Loss: 1.3485
# Validation Loss: 1.4809, Validation Accuracy: 51.24%
#
# Epoch 70/90
# Training Average Loss: 1.3557
# Validation Loss: 1.4559, Validation Accuracy: 50.72%
#
# Epoch 71/90
# Training Average Loss: 1.3518
# Validation Loss: 1.5001, Validation Accuracy: 50.33%
#
# Epoch 72/90
# Training Average Loss: 1.3467
# Validation Loss: 1.5211, Validation Accuracy: 51.24%
#
# Epoch 73/90
# Training Average Loss: 1.3591
# Validation Loss: 1.4807, Validation Accuracy: 50.07%
#
# Epoch 74/90
# Training Average Loss: 1.3528
# Validation Loss: 1.4770, Validation Accuracy: 51.76%
#
# Epoch 75/90
# Training Average Loss: 1.3457
# Validation Loss: 1.4937, Validation Accuracy: 51.37%
#
# Epoch 76/90
# Training Average Loss: 1.3324
# Validation Loss: 1.4851, Validation Accuracy: 51.63%
#
# Epoch 77/90
# Training Average Loss: 1.3218
# Validation Loss: 1.4851, Validation Accuracy: 50.33%
#
# Epoch 78/90
# Training Average Loss: 1.3471
# Validation Loss: 1.5034, Validation Accuracy: 51.76%
#
# Epoch 79/90
# Training Average Loss: 1.3229
# Validation Loss: 1.4717, Validation Accuracy: 50.98%
#
# Epoch 80/90
# Training Average Loss: 1.3486
# Validation Loss: 1.5131, Validation Accuracy: 51.37%
#
# Epoch 81/90
# Training Average Loss: 1.3483
# Validation Loss: 1.4754, Validation Accuracy: 50.85%
#
# Epoch 82/90
# Training Average Loss: 1.3191
# Validation Loss: 1.4764, Validation Accuracy: 52.15%
#
# Epoch 83/90
# Training Average Loss: 1.3095
# Validation Loss: 1.6482, Validation Accuracy: 50.59%
#
# Epoch 84/90
# Training Average Loss: 1.3393
# Validation Loss: 1.4946, Validation Accuracy: 52.02%
#
# Epoch 85/90
# Training Average Loss: 1.3162
# Validation Loss: 1.4941, Validation Accuracy: 50.59%
#
# Epoch 86/90
# Training Average Loss: 1.3541
# Validation Loss: 1.4625, Validation Accuracy: 51.24%
#
# Epoch 87/90
# Training Average Loss: 1.3232
# Validation Loss: 1.4837, Validation Accuracy: 52.80%
#
# Epoch 88/90
# Training Average Loss: 1.3345
# Validation Loss: 1.4984, Validation Accuracy: 51.50%
#
# Epoch 89/90
# Training Average Loss: 1.3168
# Validation Loss: 1.4919, Validation Accuracy: 50.59%
#
# Epoch 90/90
# Training Average Loss: 1.3483
# Validation Loss: 1.4538, Validation Accuracy: 51.89%
#
#
# -----------------------------------------------------------------
#
#
# Test Loss: 1.3389, Test Accuracy: 52.94%
# tensor(52.9412, device='cuda:0')
