# %%
import os
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, random_split, Subset
from torchmetrics.classification import Accuracy
import torchmetrics
import torchvision.models as models

import pandas as pd

from sklearn.model_selection import KFold

device= torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
train_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),  #Removed RandomCrop(32) as it resized the image back
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])   #pretrained ImageNet values
])

test_transform= transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
path= "/kaggle/input/tomato-data/data/Training_set"

# %%
full_dataset = datasets.ImageFolder(root=path, transform=train_transform)

# %%
model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
num_features = model.classifier.in_features
model.classifier = nn.Sequential(
    nn.Linear(num_features, 512),
    nn.ReLU(),
    nn.Dropout(0.3),
    nn.Linear(512, 10)
)
model = model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 165MB/s]

# %%
def train(dataloader, model, loss_function, optimizer):
  model.train()
  total_loss= 0

  for batch, (image, label) in enumerate(dataloader):
    image= image.to(device)
    label= label.to(device)

    prediction= model(image)
    loss= loss_function(prediction, label)

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    total_loss+= loss

  avg_loss= total_loss / len(dataloader)
  print(f"Training Average Loss: {avg_loss:.4f}")

# %%
val_accuracy = Accuracy(task="multiclass", num_classes=10).to(device)

def validate(dataloader, model, loss_function):
    model.eval()
    total_loss = 0
    val_accuracy.reset()

    with torch.no_grad():
        for image, label in dataloader:
            image = image.to(device)
            label = label.to(device)

            pred = model(image)
            loss = loss_function(pred, label)
            total_loss += loss

            val_accuracy.update(pred, label)

    avg_loss = total_loss / len(dataloader)
    accuracy = val_accuracy.compute() * 100  # Convert to %

    print(f"Validation Loss: {avg_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")

    return accuracy

# %%
test_accuracy = Accuracy(task="multiclass", num_classes=10).to(device)

def test(dataloader, model, loss_function):
    model.eval()
    total_loss = 0
    test_accuracy.reset()   #Reset metric state for each epoch

    with torch.no_grad():
        for image, label in dataloader:
            image = image.to(device)
            label = label.to(device)

            pred = model(image)
            loss = loss_function(pred, label)
            total_loss += loss

            test_accuracy.update(pred, label)

    avg_loss = total_loss / len(dataloader)
    accuracy = test_accuracy.compute() * 100  # Convert to %

    print(f"Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.2f}%")

    return accuracy

# %%
k_folds = 5
epochs = 50
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(kfold.split(full_dataset)):
    print(f"\n---------Fold {fold + 1}-----------")

    # Create data subsets and loaders
    train_subset = Subset(full_dataset, train_idx)
    val_subset = Subset(full_dataset, val_idx)

    train_loader = DataLoader(train_subset, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_subset, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

   
    loss_function = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=3, verbose=True)

    best_val_acc = 0.0

    for epoch in range(epochs):
        print(f"\nEpoch {epoch + 1}/{epochs}")
        train(train_loader, model, loss_function, optimizer)
        val_acc = validate(val_loader, model, loss_function)
        scheduler.step(val_acc)

        # Saving best model per fold
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), f"best_model_fold{fold+1}.pth")

    print(f"\nBest Validation Accuracy in Fold {fold + 1}: {best_val_acc:.2f}%")
    print("---------------------------------------------------------------\n")
# Out:
# ---------Fold 1-----------
#
# Epoch 1/50
# Training Average Loss: 1.5598
# Validation Loss: 1.3295, Validation Accuracy: 55.32%
#
# Epoch 2/50
# Training Average Loss: 1.4108
# Validation Loss: 1.2629, Validation Accuracy: 55.22%
#
# Epoch 3/50
# Training Average Loss: 1.3045
# Validation Loss: 1.3619, Validation Accuracy: 57.37%
#
# Epoch 4/50
# Training Average Loss: 1.2675
# Validation Loss: 1.1268, Validation Accuracy: 57.76%
#
# Epoch 5/50
# Training Average Loss: 1.2415
# Validation Loss: 1.1561, Validation Accuracy: 57.85%
#
# Epoch 6/50
# Training Average Loss: 1.1803
# Validation Loss: 1.1296, Validation Accuracy: 57.17%
#
# Epoch 7/50
# Training Average Loss: 1.1520
# Validation Loss: 1.1255, Validation Accuracy: 59.41%
#
# Epoch 8/50
# Training Average Loss: 1.1401
# Validation Loss: 1.1255, Validation Accuracy: 58.93%
#
# Epoch 9/50
# Training Average Loss: 1.0739
# Validation Loss: 1.1424, Validation Accuracy: 56.00%
#
# Epoch 10/50
# Training Average Loss: 1.1183
# Validation Loss: 1.2810, Validation Accuracy: 57.46%
#
# Epoch 11/50
# Training Average Loss: 1.0653
# Validation Loss: 0.9645, Validation Accuracy: 61.17%
#
# Epoch 12/50
# Training Average Loss: 1.0408
# Validation Loss: 1.0306, Validation Accuracy: 61.95%
#
# Epoch 13/50
# Training Average Loss: 0.9784
# Validation Loss: 1.0607, Validation Accuracy: 59.80%
#
# Epoch 14/50
# Training Average Loss: 0.9736
# Validation Loss: 1.0344, Validation Accuracy: 61.37%
#
# Epoch 15/50
# Training Average Loss: 1.0059
# Validation Loss: 1.0367, Validation Accuracy: 59.12%
#
# Epoch 16/50
# Training Average Loss: 0.9095
# Validation Loss: 0.9138, Validation Accuracy: 64.88%
#
# Epoch 17/50
# Training Average Loss: 0.9325
# Validation Loss: 0.9402, Validation Accuracy: 62.44%
#
# Epoch 18/50
# Training Average Loss: 0.8728
# Validation Loss: 0.9825, Validation Accuracy: 60.68%
#
# Epoch 19/50
# Training Average Loss: 0.9180
# Validation Loss: 1.1139, Validation Accuracy: 57.56%
#
# Epoch 20/50
# Training Average Loss: 0.8273
# Validation Loss: 0.9483, Validation Accuracy: 62.93%
#
# Epoch 21/50
# Training Average Loss: 0.7725
# Validation Loss: 0.7737, Validation Accuracy: 68.10%
#
# Epoch 22/50
# Training Average Loss: 0.7062
# Validation Loss: 0.7357, Validation Accuracy: 70.44%
#
# Epoch 23/50
# Training Average Loss: 0.6006
# Validation Loss: 0.7678, Validation Accuracy: 68.88%
#
# Epoch 24/50
# Training Average Loss: 0.6333
# Validation Loss: 0.7572, Validation Accuracy: 68.98%
#
# Epoch 25/50
# Training Average Loss: 0.5675
# Validation Loss: 0.8280, Validation Accuracy: 67.22%
#
# Epoch 26/50
# Training Average Loss: 0.5727
# Validation Loss: 0.8004, Validation Accuracy: 67.90%
#
# Epoch 27/50
# Training Average Loss: 0.5667
# Validation Loss: 0.7738, Validation Accuracy: 70.44%
#
# Epoch 28/50
# Training Average Loss: 0.5207
# Validation Loss: 0.7549, Validation Accuracy: 70.73%
#
# Epoch 29/50
# Training Average Loss: 0.5494
# Validation Loss: 0.8179, Validation Accuracy: 71.02%
#
# Epoch 30/50
# Training Average Loss: 0.5402
# Validation Loss: 0.7967, Validation Accuracy: 68.00%
#
# Epoch 31/50
# Training Average Loss: 0.5538
# Validation Loss: 0.7718, Validation Accuracy: 70.93%
#
# Epoch 32/50
# Training Average Loss: 0.4976
# Validation Loss: 0.7973, Validation Accuracy: 69.27%
#
# Epoch 33/50
# Training Average Loss: 0.5150
# Validation Loss: 0.7433, Validation Accuracy: 70.15%
#
# Epoch 34/50
# Training Average Loss: 0.5413
# Validation Loss: 0.7855, Validation Accuracy: 70.93%
#
# Epoch 35/50
# Training Average Loss: 0.5382
# Validation Loss: 0.7570, Validation Accuracy: 70.54%
#
# Epoch 36/50
# Training Average Loss: 0.5166
# Validation Loss: 0.7734, Validation Accuracy: 69.56%
#
# Epoch 37/50
# Training Average Loss: 0.5461
# Validation Loss: 0.7418, Validation Accuracy: 70.93%
#
# Epoch 38/50
# Training Average Loss: 0.5397
# Validation Loss: 0.7343, Validation Accuracy: 70.63%
#
# Epoch 39/50
# Training Average Loss: 0.5346
# Validation Loss: 0.7563, Validation Accuracy: 71.12%
#
# Epoch 40/50
# Training Average Loss: 0.5159
# Validation Loss: 0.7675, Validation Accuracy: 69.07%
#
# Epoch 41/50
# Training Average Loss: 0.5400
# Validation Loss: 0.7769, Validation Accuracy: 71.12%
#
# Epoch 42/50
# Training Average Loss: 0.5070
# Validation Loss: 0.7832, Validation Accuracy: 69.07%
#
# Epoch 43/50
# Training Average Loss: 0.5511
# Validation Loss: 0.7685, Validation Accuracy: 70.34%
#
# Epoch 44/50
# Training Average Loss: 0.5048
# Validation Loss: 0.7534, Validation Accuracy: 70.63%
#
# Epoch 45/50
# Training Average Loss: 0.5126
# Validation Loss: 0.7554, Validation Accuracy: 70.54%
#
# Epoch 46/50
# Training Average Loss: 0.5016
# Validation Loss: 0.7565, Validation Accuracy: 68.78%
#
# Epoch 47/50
# Training Average Loss: 0.5063
# Validation Loss: 0.8134, Validation Accuracy: 68.39%
#
# Epoch 48/50
# Training Average Loss: 0.5043
# Validation Loss: 0.7578, Validation Accuracy: 68.88%
#
# Epoch 49/50
# Training Average Loss: 0.4981
# Validation Loss: 0.7865, Validation Accuracy: 69.95%
#
# Epoch 50/50
# Training Average Loss: 0.5260
# Validation Loss: 0.7599, Validation Accuracy: 69.76%
#
# Best Validation Accuracy in Fold 1: 71.12%
# ---------------------------------------------------------------
#
#
# ---------Fold 2-----------
#
# Epoch 1/50
# Training Average Loss: 0.8526
# Validation Loss: 0.9511, Validation Accuracy: 67.02%
#
# Epoch 2/50
# Training Average Loss: 0.8653
# Validation Loss: 0.8177, Validation Accuracy: 66.24%
#
# Epoch 3/50
# Training Average Loss: 0.7798
# Validation Loss: 1.0061, Validation Accuracy: 63.51%
#
# Epoch 4/50
# Training Average Loss: 0.8480
# Validation Loss: 0.8688, Validation Accuracy: 64.59%
#
# Epoch 5/50
# Training Average Loss: 0.8859
# Validation Loss: 0.7268, Validation Accuracy: 69.27%
#
# Epoch 6/50
# Training Average Loss: 0.7612
# Validation Loss: 0.8610, Validation Accuracy: 65.07%
#
# Epoch 7/50
# Training Average Loss: 0.8168
# Validation Loss: 0.9177, Validation Accuracy: 62.44%
#
# Epoch 8/50
# Training Average Loss: 0.7427
# Validation Loss: 0.8488, Validation Accuracy: 65.27%
#
# Epoch 9/50
# Training Average Loss: 0.7130
# Validation Loss: 0.8422, Validation Accuracy: 64.98%
#
# Epoch 10/50
# Training Average Loss: 0.6441
# Validation Loss: 0.6455, Validation Accuracy: 72.98%
#
# Epoch 11/50
# Training Average Loss: 0.5445
# Validation Loss: 0.6616, Validation Accuracy: 70.34%
#
# Epoch 12/50
# Training Average Loss: 0.5546
# Validation Loss: 0.6402, Validation Accuracy: 72.78%
#
# Epoch 13/50
# Training Average Loss: 0.5194
# Validation Loss: 0.6470, Validation Accuracy: 73.27%
#
# Epoch 14/50
# Training Average Loss: 0.5030
# Validation Loss: 0.6452, Validation Accuracy: 73.46%
#
# Epoch 15/50
# Training Average Loss: 0.4763
# Validation Loss: 0.6888, Validation Accuracy: 72.59%
#
# Epoch 16/50
# Training Average Loss: 0.4698
# Validation Loss: 0.6729, Validation Accuracy: 72.68%
#
# Epoch 17/50
# Training Average Loss: 0.4572
# Validation Loss: 0.6408, Validation Accuracy: 73.46%
#
# Epoch 18/50
# Training Average Loss: 0.4004
# Validation Loss: 0.6406, Validation Accuracy: 74.15%
#
# Epoch 19/50
# Training Average Loss: 0.3927
# Validation Loss: 0.6726, Validation Accuracy: 72.29%
#
# Epoch 20/50
# Training Average Loss: 0.3816
# Validation Loss: 0.6635, Validation Accuracy: 73.37%
#
# Epoch 21/50
# Training Average Loss: 0.4033
# Validation Loss: 0.7041, Validation Accuracy: 73.56%
#
# Epoch 22/50
# Training Average Loss: 0.3497
# Validation Loss: 0.6690, Validation Accuracy: 74.15%
#
# Epoch 23/50
# Training Average Loss: 0.3505
# Validation Loss: 0.6236, Validation Accuracy: 75.61%
#
# Epoch 24/50
# Training Average Loss: 0.3755
# Validation Loss: 0.6699, Validation Accuracy: 74.05%
#
# Epoch 25/50
# Training Average Loss: 0.3590
# Validation Loss: 0.7033, Validation Accuracy: 72.68%
#
# Epoch 26/50
# Training Average Loss: 0.3653
# Validation Loss: 0.6537, Validation Accuracy: 74.73%
#
# Epoch 27/50
# Training Average Loss: 0.3382
# Validation Loss: 0.6828, Validation Accuracy: 73.07%
#
# Epoch 28/50
# Training Average Loss: 0.3793
# Validation Loss: 0.7023, Validation Accuracy: 73.17%
#
# Epoch 29/50
# Training Average Loss: 0.3267
# Validation Loss: 0.6972, Validation Accuracy: 73.17%
#
# Epoch 30/50
# Training Average Loss: 0.3308
# Validation Loss: 0.7104, Validation Accuracy: 72.49%
#
# Epoch 31/50
# Training Average Loss: 0.3861
# Validation Loss: 0.7840, Validation Accuracy: 70.83%
#
# Epoch 32/50
# Training Average Loss: 0.3124
# Validation Loss: 0.7275, Validation Accuracy: 72.20%
#
# Epoch 33/50
# Training Average Loss: 0.3231
# Validation Loss: 0.7386, Validation Accuracy: 71.80%
#
# Epoch 34/50
# Training Average Loss: 0.3689
# Validation Loss: 0.6572, Validation Accuracy: 75.61%
#
# Epoch 35/50
# Training Average Loss: 0.3274
# Validation Loss: 0.6977, Validation Accuracy: 72.39%
#
# Epoch 36/50
# Training Average Loss: 0.3385
# Validation Loss: 0.7166, Validation Accuracy: 72.68%
#
# Epoch 37/50
# Training Average Loss: 0.3622
# Validation Loss: 0.7433, Validation Accuracy: 73.07%
#
# Epoch 38/50
# Training Average Loss: 0.3579
# Validation Loss: 0.7006, Validation Accuracy: 71.71%
#
# Epoch 39/50
# Training Average Loss: 0.3700
# Validation Loss: 0.6539, Validation Accuracy: 73.66%
#
# Epoch 40/50
# Training Average Loss: 0.3553
# Validation Loss: 0.6878, Validation Accuracy: 75.32%
#
# Epoch 41/50
# Training Average Loss: 0.3239
# Validation Loss: 0.6946, Validation Accuracy: 72.68%
#
# Epoch 42/50
# Training Average Loss: 0.3301
# Validation Loss: 0.6542, Validation Accuracy: 74.24%
#
# Epoch 43/50
# Training Average Loss: 0.3569
# Validation Loss: 0.6762, Validation Accuracy: 74.24%
#
# Epoch 44/50
# Training Average Loss: 0.3786
# Validation Loss: 0.6792, Validation Accuracy: 73.17%
#
# Epoch 45/50
# Training Average Loss: 0.3238
# Validation Loss: 0.6842, Validation Accuracy: 73.37%
#
# Epoch 46/50
# Training Average Loss: 0.3246
# Validation Loss: 0.6928, Validation Accuracy: 73.95%
#
# Epoch 47/50
# Training Average Loss: 0.3249
# Validation Loss: 0.7228, Validation Accuracy: 71.61%
#
# Epoch 48/50
# Training Average Loss: 0.3531
# Validation Loss: 0.7085, Validation Accuracy: 74.24%
#
# Epoch 49/50
# Training Average Loss: 0.3238
# Validation Loss: 0.6579, Validation Accuracy: 74.54%
#
# Epoch 50/50
# Training Average Loss: 0.3203
# Validation Loss: 0.6568, Validation Accuracy: 73.46%
#
# Best Validation Accuracy in Fold 2: 75.61%
# ---------------------------------------------------------------
#
#
# ---------Fold 3-----------
#
# Epoch 1/50
# Training Average Loss: 0.7094
# Validation Loss: 0.6232, Validation Accuracy: 73.14%
#
# Epoch 2/50
# Training Average Loss: 0.6528
# Validation Loss: 0.6182, Validation Accuracy: 73.93%
#
# Epoch 3/50
# Training Average Loss: 0.7415
# Validation Loss: 0.7391, Validation Accuracy: 70.02%
#
# Epoch 4/50
# Training Average Loss: 0.7765
# Validation Loss: 0.6860, Validation Accuracy: 71.09%
#
# Epoch 5/50
# Training Average Loss: 1.0212
# Validation Loss: 0.7238, Validation Accuracy: 67.77%
#
# Epoch 6/50
# Training Average Loss: 0.7015
# Validation Loss: 0.8345, Validation Accuracy: 65.33%
#
# Epoch 7/50
# Training Average Loss: 0.5617
# Validation Loss: 0.5798, Validation Accuracy: 73.34%
#
# Epoch 8/50
# Training Average Loss: 0.5045
# Validation Loss: 0.5903, Validation Accuracy: 73.83%
#
# Epoch 9/50
# Training Average Loss: 0.4793
# Validation Loss: 0.5345, Validation Accuracy: 75.49%
#
# Epoch 10/50
# Training Average Loss: 0.4722
# Validation Loss: 0.5396, Validation Accuracy: 76.76%
#
# Epoch 11/50
# Training Average Loss: 0.4605
# Validation Loss: 0.5343, Validation Accuracy: 75.88%
#
# Epoch 12/50
# Training Average Loss: 0.4627
# Validation Loss: 0.5147, Validation Accuracy: 77.64%
#
# Epoch 13/50
# Training Average Loss: 0.4225
# Validation Loss: 0.5215, Validation Accuracy: 77.54%
#
# Epoch 14/50
# Training Average Loss: 0.5015
# Validation Loss: 0.5296, Validation Accuracy: 76.95%
#
# Epoch 15/50
# Training Average Loss: 0.3963
# Validation Loss: 0.5133, Validation Accuracy: 78.61%
#
# Epoch 16/50
# Training Average Loss: 0.3888
# Validation Loss: 0.5064, Validation Accuracy: 79.59%
#
# Epoch 17/50
# Training Average Loss: 0.3862
# Validation Loss: 0.5277, Validation Accuracy: 77.93%
#
# Epoch 18/50
# Training Average Loss: 0.3551
# Validation Loss: 0.5404, Validation Accuracy: 77.83%
#
# Epoch 19/50
# Training Average Loss: 0.3685
# Validation Loss: 0.5346, Validation Accuracy: 77.44%
#
# Epoch 20/50
# Training Average Loss: 0.3659
# Validation Loss: 0.5553, Validation Accuracy: 76.37%
#
# Epoch 21/50
# Training Average Loss: 0.3320
# Validation Loss: 0.5140, Validation Accuracy: 77.54%
#
# Epoch 22/50
# Training Average Loss: 0.3342
# Validation Loss: 0.5117, Validation Accuracy: 79.10%
#
# Epoch 23/50
# Training Average Loss: 0.3277
# Validation Loss: 0.5372, Validation Accuracy: 78.22%
#
# Epoch 24/50
# Training Average Loss: 0.3224
# Validation Loss: 0.5259, Validation Accuracy: 78.61%
#
# Epoch 25/50
# Training Average Loss: 0.3295
# Validation Loss: 0.5258, Validation Accuracy: 78.32%
#
# Epoch 26/50
# Training Average Loss: 0.3281
# Validation Loss: 0.5588, Validation Accuracy: 77.44%
#
# Epoch 27/50
# Training Average Loss: 0.3593
# Validation Loss: 0.5045, Validation Accuracy: 80.18%
#
# Epoch 28/50
# Training Average Loss: 0.3194
# Validation Loss: 0.5364, Validation Accuracy: 77.25%
#
# Epoch 29/50
# Training Average Loss: 0.3124
# Validation Loss: 0.5500, Validation Accuracy: 78.12%
#
# Epoch 30/50
# Training Average Loss: 0.3166
# Validation Loss: 0.5280, Validation Accuracy: 78.22%
#
# Epoch 31/50
# Training Average Loss: 0.3459
# Validation Loss: 0.5234, Validation Accuracy: 77.83%
#
# Epoch 32/50
# Training Average Loss: 0.3014
# Validation Loss: 0.5000, Validation Accuracy: 78.61%
#
# Epoch 33/50
# Training Average Loss: 0.3094
# Validation Loss: 0.5145, Validation Accuracy: 78.12%
#
# Epoch 34/50
# Training Average Loss: 0.3060
# Validation Loss: 0.5211, Validation Accuracy: 77.93%
#
# Epoch 35/50
# Training Average Loss: 0.3080
# Validation Loss: 0.5293, Validation Accuracy: 79.10%
#
# Epoch 36/50
# Training Average Loss: 0.3623
# Validation Loss: 0.5291, Validation Accuracy: 79.10%
#
# Epoch 37/50
# Training Average Loss: 0.3108
# Validation Loss: 0.5360, Validation Accuracy: 77.83%
#
# Epoch 38/50
# Training Average Loss: 0.3092
# Validation Loss: 0.5277, Validation Accuracy: 77.54%
#
# Epoch 39/50
# Training Average Loss: 0.3249
# Validation Loss: 0.5165, Validation Accuracy: 78.71%
#
# Epoch 40/50
# Training Average Loss: 0.3220
# Validation Loss: 0.5282, Validation Accuracy: 77.93%
#
# Epoch 41/50
# Training Average Loss: 0.3237
# Validation Loss: 0.5156, Validation Accuracy: 78.61%
#
# Epoch 42/50
# Training Average Loss: 0.4267
# Validation Loss: 0.5930, Validation Accuracy: 76.86%
#
# Epoch 43/50
# Training Average Loss: 0.3077
# Validation Loss: 0.5246, Validation Accuracy: 79.20%
#
# Epoch 44/50
# Training Average Loss: 0.4099
# Validation Loss: 0.5399, Validation Accuracy: 78.81%
#
# Epoch 45/50
# Training Average Loss: 0.3209
# Validation Loss: 0.5040, Validation Accuracy: 78.32%
#
# Epoch 46/50
# Training Average Loss: 0.3204
# Validation Loss: 0.4996, Validation Accuracy: 77.64%
#
# Epoch 47/50
# Training Average Loss: 0.3228
# Validation Loss: 0.5141, Validation Accuracy: 79.20%
#
# Epoch 48/50
# Training Average Loss: 0.4472
# Validation Loss: 0.5268, Validation Accuracy: 78.91%
#
# Epoch 49/50
# Training Average Loss: 0.3610
# Validation Loss: 0.5156, Validation Accuracy: 80.08%
#
# Epoch 50/50
# Training Average Loss: 0.3245
# Validation Loss: 0.5466, Validation Accuracy: 76.27%
#
# Best Validation Accuracy in Fold 3: 80.18%
# ---------------------------------------------------------------
#
#
# ---------Fold 4-----------
#
# Epoch 1/50
# Training Average Loss: 0.7570
# Validation Loss: 0.5106, Validation Accuracy: 79.20%
#
# Epoch 2/50
# Training Average Loss: 0.6674
# Validation Loss: 0.5174, Validation Accuracy: 77.05%
#
# Epoch 3/50
# Training Average Loss: 0.6952
# Validation Loss: 0.6136, Validation Accuracy: 74.32%
#
# Epoch 4/50
# Training Average Loss: 0.6581
# Validation Loss: 0.9305, Validation Accuracy: 69.63%
#
# Epoch 5/50
# Training Average Loss: 0.6234
# Validation Loss: 0.7923, Validation Accuracy: 71.29%
#
# Epoch 6/50
# Training Average Loss: 0.5337
# Validation Loss: 0.4487, Validation Accuracy: 80.66%
#
# Epoch 7/50
# Training Average Loss: 0.4639
# Validation Loss: 0.4208, Validation Accuracy: 82.13%
#
# Epoch 8/50
# Training Average Loss: 0.4635
# Validation Loss: 0.4121, Validation Accuracy: 80.76%
#
# Epoch 9/50
# Training Average Loss: 0.3933
# Validation Loss: 0.3869, Validation Accuracy: 82.81%
#
# Epoch 10/50
# Training Average Loss: 0.3598
# Validation Loss: 0.3970, Validation Accuracy: 83.50%
#
# Epoch 11/50
# Training Average Loss: 0.3861
# Validation Loss: 0.4091, Validation Accuracy: 82.52%
#
# Epoch 12/50
# Training Average Loss: 0.3940
# Validation Loss: 0.4003, Validation Accuracy: 83.11%
#
# Epoch 13/50
# Training Average Loss: 0.3729
# Validation Loss: 0.4216, Validation Accuracy: 82.81%
#
# Epoch 14/50
# Training Average Loss: 0.3347
# Validation Loss: 0.4121, Validation Accuracy: 82.32%
#
# Epoch 15/50
# Training Average Loss: 0.3170
# Validation Loss: 0.4336, Validation Accuracy: 82.13%
#
# Epoch 16/50
# Training Average Loss: 0.3220
# Validation Loss: 0.4014, Validation Accuracy: 82.81%
#
# Epoch 17/50
# Training Average Loss: 0.3000
# Validation Loss: 0.4087, Validation Accuracy: 82.81%
#
# Epoch 18/50
# Training Average Loss: 0.3397
# Validation Loss: 0.3753, Validation Accuracy: 83.98%
#
# Epoch 19/50
# Training Average Loss: 0.2928
# Validation Loss: 0.4264, Validation Accuracy: 83.01%
#
# Epoch 20/50
# Training Average Loss: 0.2988
# Validation Loss: 0.3938, Validation Accuracy: 83.89%
#
# Epoch 21/50
# Training Average Loss: 0.3004
# Validation Loss: 0.3819, Validation Accuracy: 84.86%
#
# Epoch 22/50
# Training Average Loss: 0.2878
# Validation Loss: 0.3821, Validation Accuracy: 83.59%
#
# Epoch 23/50
# Training Average Loss: 0.3346
# Validation Loss: 0.3884, Validation Accuracy: 83.69%
#
# Epoch 24/50
# Training Average Loss: 0.3424
# Validation Loss: 0.4200, Validation Accuracy: 83.01%
#
# Epoch 25/50
# Training Average Loss: 0.2837
# Validation Loss: 0.4176, Validation Accuracy: 82.42%
#
# Epoch 26/50
# Training Average Loss: 0.3142
# Validation Loss: 0.4116, Validation Accuracy: 82.91%
#
# Epoch 27/50
# Training Average Loss: 0.2885
# Validation Loss: 0.4105, Validation Accuracy: 82.81%
#
# Epoch 28/50
# Training Average Loss: 0.2791
# Validation Loss: 0.3951, Validation Accuracy: 83.50%
#
# Epoch 29/50
# Training Average Loss: 0.2833
# Validation Loss: 0.3991, Validation Accuracy: 82.52%
#
# Epoch 30/50
# Training Average Loss: 0.2940
# Validation Loss: 0.3962, Validation Accuracy: 83.01%
#
# Epoch 31/50
# Training Average Loss: 0.2706
# Validation Loss: 0.3994, Validation Accuracy: 82.91%
#
# Epoch 32/50
# Training Average Loss: 0.2769
# Validation Loss: 0.4062, Validation Accuracy: 83.40%
#
# Epoch 33/50
# Training Average Loss: 0.2827
# Validation Loss: 0.4106, Validation Accuracy: 82.81%
#
# Epoch 34/50
# Training Average Loss: 0.3140
# Validation Loss: 0.4143, Validation Accuracy: 83.20%
#
# Epoch 35/50
# Training Average Loss: 0.2843
# Validation Loss: 0.3757, Validation Accuracy: 84.18%
#
# Epoch 36/50
# Training Average Loss: 0.2897
# Validation Loss: 0.4208, Validation Accuracy: 82.91%
#
# Epoch 37/50
# Training Average Loss: 0.2883
# Validation Loss: 0.3976, Validation Accuracy: 83.59%
#
# Epoch 38/50
# Training Average Loss: 0.2724
# Validation Loss: 0.3995, Validation Accuracy: 84.18%
#
# Epoch 39/50
# Training Average Loss: 0.2991
# Validation Loss: 0.3990, Validation Accuracy: 83.30%
#
# Epoch 40/50
# Training Average Loss: 0.2845
# Validation Loss: 0.4099, Validation Accuracy: 83.40%
#
# Epoch 41/50
# Training Average Loss: 0.3290
# Validation Loss: 0.3807, Validation Accuracy: 84.86%
#
# Epoch 42/50
# Training Average Loss: 0.2899
# Validation Loss: 0.4023, Validation Accuracy: 83.01%
#
# Epoch 43/50
# Training Average Loss: 0.3106
# Validation Loss: 0.4061, Validation Accuracy: 83.01%
#
# Epoch 44/50
# Training Average Loss: 0.2872
# Validation Loss: 0.3893, Validation Accuracy: 84.47%
#
# Epoch 45/50
# Training Average Loss: 0.2744
# Validation Loss: 0.4132, Validation Accuracy: 82.81%
#
# Epoch 46/50
# Training Average Loss: 0.3246
# Validation Loss: 0.4051, Validation Accuracy: 82.32%
#
# Epoch 47/50
# Training Average Loss: 0.2750
# Validation Loss: 0.3866, Validation Accuracy: 84.77%
#
# Epoch 48/50
# Training Average Loss: 0.2842
# Validation Loss: 0.4046, Validation Accuracy: 82.52%
#
# Epoch 49/50
# Training Average Loss: 0.3164
# Validation Loss: 0.4036, Validation Accuracy: 83.59%
#
# Epoch 50/50
# Training Average Loss: 0.2747
# Validation Loss: 0.3884, Validation Accuracy: 83.40%
#
# Best Validation Accuracy in Fold 4: 84.86%
# ---------------------------------------------------------------
#
#
# ---------Fold 5-----------
#
# Epoch 1/50
# Training Average Loss: 0.6257
# Validation Loss: 0.4960, Validation Accuracy: 78.91%
#
# Epoch 2/50
# Training Average Loss: 0.5973
# Validation Loss: 0.6721, Validation Accuracy: 73.44%
#
# Epoch 3/50
# Training Average Loss: 0.6848
# Validation Loss: 0.6025, Validation Accuracy: 74.41%
#
# Epoch 4/50
# Training Average Loss: 0.5433
# Validation Loss: 0.6253, Validation Accuracy: 74.71%
#
# Epoch 5/50
# Training Average Loss: 0.6414
# Validation Loss: 1.0549, Validation Accuracy: 60.74%
#
# Epoch 6/50
# Training Average Loss: 0.7372
# Validation Loss: 0.6781, Validation Accuracy: 72.36%
#
# Epoch 7/50
# Training Average Loss: 0.5875
# Validation Loss: 0.6012, Validation Accuracy: 74.32%
#
# Epoch 8/50
# Training Average Loss: 0.5114
# Validation Loss: 0.5184, Validation Accuracy: 79.20%
#
# Epoch 9/50
# Training Average Loss: 0.4466
# Validation Loss: 0.4997, Validation Accuracy: 79.79%
#
# Epoch 10/50
# Training Average Loss: 0.4142
# Validation Loss: 0.4527, Validation Accuracy: 80.76%
#
# Epoch 11/50
# Training Average Loss: 0.4274
# Validation Loss: 0.4520, Validation Accuracy: 81.35%
#
# Epoch 12/50
# Training Average Loss: 0.3804
# Validation Loss: 0.4344, Validation Accuracy: 80.47%
#
# Epoch 13/50
# Training Average Loss: 0.3563
# Validation Loss: 0.4404, Validation Accuracy: 82.71%
#
# Epoch 14/50
# Training Average Loss: 0.4217
# Validation Loss: 0.4314, Validation Accuracy: 82.62%
#
# Epoch 15/50
# Training Average Loss: 0.3470
# Validation Loss: 0.4313, Validation Accuracy: 80.57%
#
# Epoch 16/50
# Training Average Loss: 0.3097
# Validation Loss: 0.3966, Validation Accuracy: 83.11%
#
# Epoch 17/50
# Training Average Loss: 0.3036
# Validation Loss: 0.4344, Validation Accuracy: 81.25%
#
# Epoch 18/50
# Training Average Loss: 0.2961
# Validation Loss: 0.4061, Validation Accuracy: 83.30%
#
# Epoch 19/50
# Training Average Loss: 0.3029
# Validation Loss: 0.4341, Validation Accuracy: 81.84%
#
# Epoch 20/50
# Training Average Loss: 0.2739
# Validation Loss: 0.4128, Validation Accuracy: 83.40%
#
# Epoch 21/50
# Training Average Loss: 0.2694
# Validation Loss: 0.3856, Validation Accuracy: 82.71%
#
# Epoch 22/50
# Training Average Loss: 0.3663
# Validation Loss: 0.4421, Validation Accuracy: 81.25%
#
# Epoch 23/50
# Training Average Loss: 0.3217
# Validation Loss: 0.3978, Validation Accuracy: 84.18%
#
# Epoch 24/50
# Training Average Loss: 0.2463
# Validation Loss: 0.4502, Validation Accuracy: 80.96%
#
# Epoch 25/50
# Training Average Loss: 0.2545
# Validation Loss: 0.4010, Validation Accuracy: 84.08%
#
# Epoch 26/50
# Training Average Loss: 0.2324
# Validation Loss: 0.4021, Validation Accuracy: 83.79%
#
# Epoch 27/50
# Training Average Loss: 0.2606
# Validation Loss: 0.3991, Validation Accuracy: 83.20%
#
# Epoch 28/50
# Training Average Loss: 0.2225
# Validation Loss: 0.4051, Validation Accuracy: 83.11%
#
# Epoch 29/50
# Training Average Loss: 0.2057
# Validation Loss: 0.4017, Validation Accuracy: 83.50%
#
# Epoch 30/50
# Training Average Loss: 0.1978
# Validation Loss: 0.3743, Validation Accuracy: 83.89%
#
# Epoch 31/50
# Training Average Loss: 0.2172
# Validation Loss: 0.4224, Validation Accuracy: 82.32%
#
# Epoch 32/50
# Training Average Loss: 0.2130
# Validation Loss: 0.3827, Validation Accuracy: 83.40%
#
# Epoch 33/50
# Training Average Loss: 0.2165
# Validation Loss: 0.4037, Validation Accuracy: 83.89%
#
# Epoch 34/50
# Training Average Loss: 0.2007
# Validation Loss: 0.3637, Validation Accuracy: 86.04%
#
# Epoch 35/50
# Training Average Loss: 0.2528
# Validation Loss: 0.4176, Validation Accuracy: 83.69%
#
# Epoch 36/50
# Training Average Loss: 0.1902
# Validation Loss: 0.3858, Validation Accuracy: 84.57%
#
# Epoch 37/50
# Training Average Loss: 0.2347
# Validation Loss: 0.4106, Validation Accuracy: 82.91%
#
# Epoch 38/50
# Training Average Loss: 0.2599
# Validation Loss: 0.3780, Validation Accuracy: 83.69%
#
# Epoch 39/50
# Training Average Loss: 0.2725
# Validation Loss: 0.4053, Validation Accuracy: 83.30%
#
# Epoch 40/50
# Training Average Loss: 0.2061
# Validation Loss: 0.3902, Validation Accuracy: 83.59%
#
# Epoch 41/50
# Training Average Loss: 0.2050
# Validation Loss: 0.3636, Validation Accuracy: 85.45%
#
# Epoch 42/50
# Training Average Loss: 0.2294
# Validation Loss: 0.3751, Validation Accuracy: 84.28%
#
# Epoch 43/50
# Training Average Loss: 0.2422
# Validation Loss: 0.3669, Validation Accuracy: 85.45%
#
# Epoch 44/50
# Training Average Loss: 0.2002
# Validation Loss: 0.3777, Validation Accuracy: 83.89%
#
# Epoch 45/50
# Training Average Loss: 0.1958
# Validation Loss: 0.4010, Validation Accuracy: 83.30%
#
# Epoch 46/50
# Training Average Loss: 0.2064
# Validation Loss: 0.4035, Validation Accuracy: 82.71%
#
# Epoch 47/50
# Training Average Loss: 0.1986
# Validation Loss: 0.3846, Validation Accuracy: 84.28%
#
# Epoch 48/50
# Training Average Loss: 0.1984
# Validation Loss: 0.4126, Validation Accuracy: 82.91%
#
# Epoch 49/50
# Training Average Loss: 0.2013
# Validation Loss: 0.4388, Validation Accuracy: 81.93%
#
# Epoch 50/50
# Training Average Loss: 0.1923
# Validation Loss: 0.4057, Validation Accuracy: 83.40%
#
# Best Validation Accuracy in Fold 5: 86.04%
# ---------------------------------------------------------------
